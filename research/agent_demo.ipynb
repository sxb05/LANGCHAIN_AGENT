# %%
import os
from dotenv import load_dotenv
import certifi
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain.agents import create_agent

# %%
os.environ["SSL_CERT_FILE"] = certifi.where()
load_dotenv()

OPEN_API_KEY = os.getenv("OPEN_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
search_tool = TavilySearchResults(max_results=2)
# Out:
# D:\Temp\Temp\ipykernel_3368\919418145.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   search_tool = TavilySearchResults(max_results=2)

# %%
result = search_tool.invoke("Give me the latest news on AI and machine learning.")
result
# Out:
# [{'title': 'AI and machine learning News, Stories and Latest Updates 2025',
#   'url': 'https://analyticsindiamag.com/news/ai-and-machine-learning',
#   'content': '# AI and machine learning News & Updates in 2025. ## Latest News and Stories About AI and machine learning in 2025. ### PM Modi Urges Youth to Embrace AI, Machine Learning. “This era has moved beyond machines to machine learning.”. Hugging Face provides abundant tools to build textual or visual AI models ethically. ### AI-powered Audio Transcription Tools To Check Out In 2021. Researchers and technologists around the globe are now striving to develop artificial general intelligence (AGI) in order to achieve one common target — build efficient models which are more human-like. Now, China has been pushing itself to accelerate AI quite seriously and has been doing massive investments in this sector. Gradient Boosting Decision Tree is a widely-used machine learning algorithm for classification and regression problems. This is not a new topic for machine learning developers. GBDT achieves state-of-the-art performance in various machine learning tasks due to its efficiency, accuracy, and interpretability. ### Google Researchers Explore A New Paradigm For Partial Differential Equations With Machine Learning. ### 10 Algorithms Every Machine Learning Enthusiast Should Know. It is very crucial for the machine learning enthusiasts to know and understands the basic and important machine learning algorithms in order to keep themselves up with the current trend. In this article, we list down 10 basic algorithms which play very important roles in the machine learning era. Humans are already heavily depended on machines in some way or the other and in the meantime, developments in the field of artificial intelligence and machine learning are moving at a breakneck speed. ### Detecting loan defaults at an early stage using models of machine intelligence. 7 Must-Read Books on AI in 2025. Top 10 Indian Startups Powering Healthcare with AI. 7 AI Startups That Failed in 2025. 7 Times AI Went to Court in 2025. 9 Indian AI Research Papers From 2025 That Deserve More Attention. 8 Times AI Startups Turned into Acquisition Targets. The One-Stop Guide To The Top AI Governance Guidelines & Researches. A Beginner’s Guide to Time Series Modelling Using PyCaret. A Guide to VARMA with Grid Search in Time-Series Modelling. A Beginner’s Guide to Two-Phase Learning.',
#   'score': 0.9147261},
#  {'title': 'AI Breakthroughs: Tech News on Machine Learning Advancements',
#   'url': 'https://itnation.info/tech_news/ai_machine_learning/226-ai_breakthroughs_tech_news_on_machine_learning_advancements',
#   'content': '# AI Breakthroughs: Tech News on Machine Learning Advancements. Home / Tech News / AI & Machine Learning # AI Breakthroughs: Tech News on Machine Learning Advancements June 18, 2025, 6:32 pm : x: facebook: linkedin: pinterest: telegram: share : AI Breakthroughs: Tech News on Machine Learning Advancements **Artificial Intelligence (AI)** continues to make significant strides, particularly in the realm of machine learning. Machine learning algorithms are at the forefront of these developments, enabling computers to learn from data and make decisions without explicit programming. Despite the remarkable progress in AI and machine learning, there are challenges that need to be addressed. In conclusion, the recent AI breakthroughs in machine learning are reshaping industries and opening up new possibilities for innovation. From deep learning advancements to applications in healthcare, finance, and autonomous vehicles, AI is driving transformative change across various sectors. ## Common questions that brought readers here * artificial intelligence in machine learning * latest tech news advancements * deep learning success in tasks * integration of AI in healthcare * AI-powered algorithms in finance * autonomous vehicles with AI systems * ethical use of AI systems * transformative change in industries * balance between innovation and responsibility * how AI is revolutionizing technology * best practices for AI deployment * guide to ethical AI development * tips for leveraging AI in finance * AI applications in healthcare industry * step-by-step deep learning process * AI impact on autonomous driving * AI regulations and guidelines * benefits of AI in various sectors * AI challenges and solutions ## Add comment Your name Your email Your comment (Minimum 30 characters) Verification code : CaptchaRecommended articles : AI Unleashed: Tech News on Machine Learning BreakthroughsAI Unleashed: Tech News on Machine Learning Breakthroughs December 2, 2025, 11:30 am : AI Breakthroughs: Future Trends in Machine LearningAI Breakthroughs: Future Trends in Machine Learning November 1, 2025, 3:50 pm : AI Breakthroughs: Unveiling Cutting-Edge Machine Learning TrendsAI Breakthroughs: Unveiling Cutting-Edge Machine Learning Trends September 30, 2025, 2:12 pm : AI Insights: Latest Machine Learning Trends UnveiledAI Insights: Latest Machine Learning Trends Unveiled August 31, 2025, 11:41 am AI Evolution: Latest Machine Learning Trends Unveiled August 10, 2025, 6:21 pm.',
#   'score': 0.84027237}]

# %%
# import google.generativeai as genai
# import os

# genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# for m in genai.list_models():
#     if 'generateContent' in m.supported_generation_methods:
#         print(m.name)

# %%
# print("Google key exists:", bool(os.getenv("GOOGLE_API_KEY")))

# gemini_llm = ChatGoogleGenerativeAI(
#     model="gemini-pro",
#     temperature=0, google_api_key= GOOGLE_API_KEY
# )

# print("LLM type:", type(gemini_llm))

# response = gemini_llm.invoke("What is an AI agent?")
# print(response.content)

# %%
# response = llm.invoke("Give me the latest news on AI and machine learning.")
# response

# %%
# Gemini
llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

# %%
response = llm.invoke("Tell me a joke about AI")
response
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'How many AIs does it take to change a lightbulb?\n\nNone. It will just generate a photo of a lightbulb... but the hand holding it will have seven fingers.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a052d2-30ad-70a1-a955-82b552dbe5d5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 1278, 'total_tokens': 1285, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1241}})
